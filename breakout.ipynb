# %%
# %env XLA_PYTHON_CLIENT_PREALLOCATE=false
from dataclasses import dataclass
from jax import random, numpy as jnp
import optax
import equinox as eqx
from pathlib import Path
from tqdm import trange
import gym
import pandas as pd
import timeit

from src.actorcritic import ActorCritic
from src.training import policy_trajectory, step_model_ppo

import warnings
warnings.filterwarnings("ignore")


@dataclass
class Hyperparameters:
    batchsize=1
    epochs=50000
    steps_per_episode=1000
    learning_rate=0.003
    reward_discount=0.99
    epsilon=0.2

hyperparameters = Hyperparameters()


if __name__ == "__main__":
    env = gym.make("ALE/Breakout-v5")
    observation = env.reset()
    print(observation.flatten(), env.action_space.n)

    key = random.PRNGKey(0)
    agent = ActorCritic(observation.flatten().shape[0], env.action_space.n, [64], [64], key=key)

    optimizer = optax.adam(hyperparameters.learning_rate)
    optimizer_state = optimizer.init(eqx.filter(agent, eqx.filters.is_array))

    env.seed(0)

    # with jax.profiler.trace("/tmp/jax-trace", create_perfetto_link=True):
    df = pd.DataFrame(columns=["time", "parameters", "avg_reward"])
    for epoch in (pbar := trange(hyperparameters.epochs)):
        batch_rewards = []

        for batchsize in range(hyperparameters.batchsize):
            key = random.split(key, 2)[1]

            import timeit

            start = timeit.default_timer()

            trajectory = policy_trajectory(
                env,
                agent,
                hyperparameters.steps_per_episode,
                hyperparameters.reward_discount,
                key,
            )

            loss, agent, optimizer_state = step_model_ppo(
                agent, trajectory, optimizer, optimizer_state
            )

            try:
                trajectory_reward = jnp.where(trajectory["discounts"] == 0.0)[0][0]
            except:
                trajectory_reward = hyperparameters.steps_per_episode
            batch_rewards.append(trajectory_reward)
        avg_reward = jnp.array(batch_rewards).mean()
        pbar.set_description(f"{avg_reward}")
        save_path = Path(f"checkpoints/breakout/checkpoint_{epoch}.eqx")
        save_path.parent.mkdir(parents=True, exist_ok=True)
        df = pd.concat(
            [
                df,
                pd.DataFrame(
                    {
                        "time": epoch,
                        "parameters": save_path.absolute().as_posix(),
                        # "loss": loss,
                        "avg_reward": avg_reward,
                    },
                    index=[0],
                ),
            ],
            ignore_index=True,
        )
        if epoch % 100 == 0:
            eqx.tree_serialise_leaves(save_path, agent)
            pd.to_pickle(df, save_path.parent / f"data_{epoch}.pkl")

    # %%
# Out:
# env: XLA_PYTHON_CLIENT_PREALLOCATE=false
# A.L.E: Arcade Learning Environment (version 0.7.5+db37282)
# [Powered by Stella]
# [0 0 0 ... 0 0 0] 4
# 224.0:  50%|█████     | 501/1000 [13:04<13:01,  1.57s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb Cell 1 in <cell line: 31>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=51'>52</a> import timeit
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a> start = timeit.default_timer()
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=55'>56</a> trajectory = policy_trajectory(
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=56'>57</a>     env,
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=57'>58</a>     agent,
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=58'>59</a>     hyperparameters.steps_per_episode,
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=59'>60</a>     hyperparameters.reward_discount,
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=60'>61</a>     key,
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=61'>62</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=63'>64</a> loss, agent, optimizer_state = step_model_ppo(
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=64'>65</a>     agent, trajectory, optimizer, optimizer_state
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=65'>66</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Bdella-gpu/home/samyakg/tigress/Reinforcement-Learning-In-JAX/breakout.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=67'>68</a> try:
#
# File /tigress/samyakg/Reinforcement-Learning-In-JAX/src/training.py:89, in policy_trajectory(env, agent, steps_per_episode, gamma, key)
#      86 # discounts of 0.0 are used to signal terminal states
#      87 discounts_mask[step] = 0.0 if done else 1.0
# ---> 89 action, action_logits = agent.act_with_logits(observation, keys[step])
#      90 observation, reward, done, info = env.step(action.item())
#      91 observation = device_put(jnp.array(observation).flatten())
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3597, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    3594   return _getslice(arr, start, stop)
#    3596 treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 3597 return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    3598                unique_indices, mode, fill_value)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3606, in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    3603 def _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    3604             unique_indices, mode, fill_value):
#    3605   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 3606   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    3607   y = arr
#    3609   if fill_value is not None:
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3806, in _index_to_gather(x_shape, idx, normalize_indices)
#    3803 if core.symbolic_equal_dim(x_shape[x_axis], 0):
#    3804   # XLA gives error when indexing into an axis of size 0
#    3805   raise IndexError(f"index is out of bounds for axis {x_axis} with size 0")
# -> 3806 i = _normalize_index(i, x_shape[x_axis]) if normalize_indices else i
#    3807 i = lax.convert_element_type(i, index_dtype)
#    3808 gather_indices.append((i, len(gather_indices_shape)))
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3480, in _normalize_index(index, axis_size)
#    3476 else:
#    3477   axis_size_val = lax.convert_element_type(core.dimension_as_value(axis_size),
#    3478                                            _dtype(index))
#    3479 return lax.select(
# -> 3480   lax.lt(index, _lax_const(index, 0)),
#    3481   lax.add(index, axis_size_val),
#    3482   index)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/lax/lax.py:511, in lt(x, y)
#     509 def lt(x: Array, y: Array) -> Array:
#     510   r"""Elementwise less-than: :math:`x < y`."""
# --> 511   return lt_p.bind(x, y)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/core.py:324, in Primitive.bind(self, *args, **params)
#     321 def bind(self, *args, **params):
#     322   assert (not config.jax_enable_checks or
#     323           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 324   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/core.py:327, in Primitive.bind_with_trace(self, trace, args, params)
#     326 def bind_with_trace(self, trace, args, params):
# --> 327   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     328   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/core.py:684, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     683 def process_primitive(self, primitive, tracers, params):
# --> 684   return primitive.impl(*tracers, **params)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/dispatch.py:101, in apply_primitive(prim, *args, **params)
#      98 """Impl rule that compiles and runs a single primitive 'prim' using XLA."""
#      99 compiled_fun = xla_primitive_callable(prim, *unsafe_map(arg_spec, args),
#     100                                       **params)
# --> 101 return compiled_fun(*args)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/dispatch.py:167, in xla_primitive_callable.<locals>.<lambda>(*args, **kw)
#     164 compiled = _xla_callable_uncached(lu.wrap_init(prim_fun), device, None,
#     165                                   prim.name, donated_invars, False, *arg_specs)
#     166 if not prim.multiple_results:
# --> 167   return lambda *args, **kw: compiled(*args, **kw)[0]
#     168 else:
#     169   return compiled
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/dispatch.py:728, in _execute_compiled(name, compiled, input_handler, output_buffer_counts, result_handler, has_unordered_effects, ordered_effects, kept_var_idx, *args)
#     726 device, = compiled.local_devices()
#     727 args, env = input_handler(args) if input_handler else (args, None)
# --> 728 in_flat = flatten(device_put(x, device) for i, x in enumerate(args)
#     729                   if i in kept_var_idx)
#     730 if has_unordered_effects or ordered_effects:
#     731   in_flat, token_handler = _add_tokens(has_unordered_effects, ordered_effects,
#     732                                        device, in_flat)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/util.py:111, in concatenate(xs)
#     109 def concatenate(xs: Iterable[Sequence[T]]) -> List[T]:
#     110   """Concatenates/flattens a list of lists."""
# --> 111   return list(it.chain.from_iterable(xs))
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/dispatch.py:728, in <genexpr>(.0)
#     726 device, = compiled.local_devices()
#     727 args, env = input_handler(args) if input_handler else (args, None)
# --> 728 in_flat = flatten(device_put(x, device) for i, x in enumerate(args)
#     729                   if i in kept_var_idx)
#     730 if has_unordered_effects or ordered_effects:
#     731   in_flat, token_handler = _add_tokens(has_unordered_effects, ordered_effects,
#     732                                        device, in_flat)
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/dispatch.py:999, in device_put(x, device)
#     997 x = xla.canonicalize_dtype(x)
#     998 try:
# --> 999   return device_put_handlers[type(x)](x, device)
#    1000 except KeyError as err:
#    1001   raise TypeError(f"No device_put handler for type: {type(x)}") from err
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/dispatch.py:1007, in _device_put_array(x, device)
#    1006 def _device_put_array(x, device: Optional[Device]):
# -> 1007   backend = xb.get_device_backend(device)
#    1008   if x.dtype == dtypes.float0:
#    1009     x = np.zeros(x.shape, dtype=np.dtype(bool))
#
# File ~/.conda/envs/rl-in-jax/lib/python3.9/site-packages/jax/_src/lib/xla_bridge.py:406, in get_device_backend(device)
#     404 """Returns the Backend associated with `device`, or the default Backend."""
#     405 if device is not None:
# --> 406   return device.client
#     407 return get_backend()
#
# KeyboardInterrupt:

# %%
# Render an episode and save as a GIF file

from IPython import display as ipythondisplay
from PIL import Image
from pyvirtualdisplay import Display
import gym
from src.actorcritic import ActorCritic
import equinox as eqx
import jax
import jax.numpy as jnp

display = Display(visible=0, size=(400, 300))
display.start()


def render_episode(env: gym.Env, model: ActorCritic, max_steps: int, key: jax.random.KeyArray): 
  screen = env.render(mode='rgb_array')
  im = Image.fromarray(screen)

  images = [im]

  state = jnp.array(env.reset()).flatten()
  for i in range(1, max_steps + 1):
    key = jax.random.split(key, 2)[1]
    action = model.act(state, key)
    state, _, done, _ = env.step(action.item())
    state = jnp.array(state).flatten()

    # Render screen every 10 steps
    if i % 10 == 0:
      screen = env.render(mode='rgb_array')
      images.append(Image.fromarray(screen))


  return images


# Save GIF image
observation = jnp.array(env.reset())
key = jax.random.PRNGKey(0)
images = render_episode(env, eqx.tree_deserialise_leaves("checkpoints/breakout/checkpoint_500.eqx", ActorCritic(observation.flatten().shape[0], env.action_space.n, [64], [64], key=key)), 1000, key=key)
image_file = 'breakout.gif'
# loop=0: loop forever, duration=1: play each frame for 1ms
images[0].save(
    image_file, save_all=True, append_images=images[1:], loop=0, duration=1)
